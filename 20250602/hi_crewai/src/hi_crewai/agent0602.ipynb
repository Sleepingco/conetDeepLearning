# %%
from dotenv import load_dotenv
import os
print('API Key loaded',os.getenv("OPENAI_API_KEY"))

# %%
from crewai import Agent, Task, Crew, Process # CrewAI 핵심 클래스들
from dotenv import load_dotenv
import os

# 0 환경변수 로드(.env에서 OPENAI_API_KEY 불러오기)
load_dotenv() # .env 파일에 정의된 환경변수를 로드합니다.
# OPENAI_API_KEY가 환경변수로 설정되엇다면,openai패키지가 이를 자동으로 사용합니다.

# 1.Agent 생성:role,goal,backstory 설정
agent = Agent(
    role='AI 어시스턴트', # 에이전트의 역할
    goal='사용자에게 간단한 환영 인사를 제공', # 에이전트가 달성할 목표
    backstory='당신은 친절한 AI비서로, 언제나 정중하고 도움이 되는 인사를 건넵니다' # 에이전트의 성격/배경

)

# %%
# Task 생성: description, expected_outpuy,agent
task = Task(
    description='사용자에게 환영 인사 한 마디를 작성하세요', # 에이전트가 수행할 작업 내용
    expected_output='한 줄의 따뜻한 환영 메세지', # 기대하는 출력 결과물
    agent = agent
)

# %%
# 3. Crew 생성: 에이전트와 태스크를 크루로 구성 (순차 프로세스 설정)
crew = Crew(
    agents=[agent], # 크루에 속한 에이전트 목록 (여기서는 1개)
    tasks=[task], # 크루가 수행할 태스크 목록 (여기서는 1개)
    process=Process.sequential, # 순차적 진행 방식으로 태스크 실행
    verbose=False # 실행 중 상세한 로그 출력 여부
)

# %%
# 4. Crew 실행: kickoff() 메서드로 태스크 수행 시작
result = crew.kickoff()
# 5. 실행 결과 출력
print("최종 결과:", result)
# Out:
# 최종 결과: 환영합니다! 오늘도 좋은 하루 되세요!

# %%
# 필요한 라이브러리 임포트
from crewai import Agent, Task, Crew, Process # CrewAI 핵심 클래스들
from dotenv import load_dotenv
import os
# 0. 환경 변수 로드 (.env에서 OPENAI_API_KEY 불러오기)
load_dotenv() # .env 파일에 정의된 환경변수를 로드합니다.
# OPENAI_API_KEY가 환경변수로 설정되었다면, openai 패키지가 이를 자동으로 사용합니다.
# 1. Agent 생성: role, goal, backstory 설정
agent = Agent(
    role="{topic} AI 어시스턴트", # 에이전트의 역할
    goal="{topic} 사용자에게 간단한 환영 인사를 제공", # 에이전트가 달성할 목표
    backstory="당신은 친절한 AI 비서로, {topic}에서 언제나 정중하고 도움이 되는 인사를 건넵니다." # 에이전트의 성격/배경
)
# 2. Task 생성: description, expected_output, agent 지정
task = Task(
    description="{topic}에 참석한 사용자에게 환영 인사 한 마디를 작성하세요.", # 에이전트가 수행할 작업 내용
    expected_output="{topic}에서의 한 줄의 따뜻한 환영 메시지", # 기대하는 출력 결과물
    agent=agent # 이 태스크를 수행할 에이전트
)

# %%
# 3. Crew 생성: 에이전트와 태스크를 크루로 구성 (순차 프로세스 설정)
crew = Crew(
    agents=[agent], # 크루에 속한 에이전트 목록 (여기서는 1개)
    tasks=[task], # 크루가 수행할 태스크 목록 (여기서는 1개)
    process=Process.sequential, # 순차적 진행 방식으로 태스크 실행
    verbose=True # 실행 중 상세한 로그 출력 여부
)

# %%
# 4. Crew 실행: kickoff() 메서드로 태스크 수행 시작
inputs = {
    "topic": "결혼식"
}

# %%
result = crew.kickoff(inputs=inputs)
# Out:
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 06b1ca0b-e266-4579-9813-082d32eb7abf                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: 결혼식 AI 어시스턴트
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
# ## Task: 결혼식에 참석한 사용자에게 환영 인사 한 마디를 작성하세요.
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
# mExecuting Task...
#
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
# # Agent: 결혼식 AI 어시스턴트
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
# ## Final Answer:
# 결혼식에 참석해 주셔서 진심으로 감사합니다. 오늘 이 특별한 날을 여러분과 함께
# 나누게 되어 매우 기쁩니다!
#
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
# mExecuting Task...
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
#     Assigned to: 결혼식 AI 어시스턴트
# 🚀 Crew: crew
# └── 📋 Task: f672e49a-7277-468f-a042-601eaa1c0751
#     Assigned to: 결혼식 AI 어시스턴트
#     Status: ✅ Completed
# ┌────────────────────────────── Task Completion ──────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: f672e49a-7277-468f-a042-601eaa1c0751                                 │
# │  Agent: 결혼식 AI 어시스턴트                                                │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌────────────────────────────── Crew Completion ──────────────────────────────┐
# │                                                                             │
# │  Crew Execution Completed                                                   │
# │  Name: crew                                                                 │
# │  ID: 06b1ca0b-e266-4579-9813-082d32eb7abf                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘

# %%
# 5. 실행 결과 출력
print("최종 결과:", result)
# Out:
# 최종 결과: 결혼식에 참석해 주셔서 진심으로 감사합니다. 오늘 이 특별한 날을 여러분과 함께 나누게 되어 매우 기쁩니다!

# %%
import os
from dotenv import load_dotenv
from crewai import Agent, Task, Crew, Process
# 1. .env 파일에서 OpenAI API 키 불러오기
load_dotenv()
openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key is None:
 raise EnvironmentError("OPENAI_API_KEY is not set in .env file. Please add your OpenAI API key to .env.")

# %%
# 2. 에이전트 정의 (연구원, 작가)
researcher = Agent(
 role="AI Researcher",
 goal="멀티 에이전트 시스템의 주요 장점을 3가지 조사하여 설명합니다.",
 backstory="다년간 AI 트렌드를 연구해온 전문가입니다."
)
writer = Agent(
 role="Technical Writer",
 goal="연구 결과를 바탕으로 간략한 결론을 작성합니다.",
 backstory="복잡한 정보를 쉽게 요약하는 작문 전문가입니다."
)

# %%
# 3. 태스크 정의 (조사 태스크, 작성 태스크)
research_task = Task(
    description="멀티 에이전트 시스템의 주요 장점 3가지를 조사하고 각 장점을 간략히 설명하세요.",
    expected_output="3가지 장점에 대한 간단한 설명 (bullet point 목록)",
    agent=researcher
)
write_task = Task(
    description="위 조사 결과를 참고하여, 멀티 에이전트 시스템의 장점에 대한 짧은 결론을 작성하세요.",
    expected_output="3~4문장으로 구성된 결론 단락",
    agent=writer,
    context=[research_task] # 이전 태스크의 결과를 활용
)

# %%
# 4. 크루 생성 (순차적 프로세스 설정)
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True
)

# %%
# 5. 크루 실행 및 결과 출력
crew_output = crew.kickoff()
# 6. 각 태스크의 결과를 순차적으로 출력
for idx, task_output in enumerate(crew_output.tasks_output, start=1):
 print(f"\n[Task {idx} Output]\n{task_output}\n")
# Out:
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 9c5bbe8e-fa04-4f99-8820-d5cbf7f4e4f6                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: AI Researcher
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# ## Task: 멀티 에이전트 시스템의 주요 장점 3가지를 조사하고 각 장점을 간략히
# 설명하세요.
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# mExecuting Task...
#
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# # Agent: AI Researcher
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# ## Final Answer:
# - **분산 처리와 확장성**: 멀티 에이전트 시스템은 여러 개의 개별 에이전트가
# 독립적으로 작업을 수행할 수 있게 하기 때문에, 작업을 효율적으로 나눠 처리할 수
# 있습니다. 이 방식은 시스템의 확장성을 높여, 더 많은 에이전트를 추가함으로써
# 처리 능력을 쉽게 늘릴 수 있게 합니다.
#
# - **신뢰성 및 내결함성**: 여러 개의 에이전트가 서로 협력하며 작업을 수행하기
# 때문에, 하나의 에이전트가 실패하더라도 다른 에이전트들이 그 작업을 대체하거나
# 협력하여 시스템의 전체 기능이 감소하지 않습니다. 이로 인해 전체 시스템의
# 신뢰성과 내결함성이 향상됩니다.
#
# - **복잡한 문제 해결능력**: 멀티 에이전트 시스템은 다양한 개체들이 상호작용할
# 수 있도록 설계되어 복잡한 문제를 해결하는 데 효과적입니다. 에이전트들 간의
# 협업과 경쟁을 통해, 다양한 해결책을 모색할 수 있어 더 창의적이고 효율적인
# 결과를 도출할 수 있습니다.
#
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# mExecuting Task...
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Assigned to: AI Researcher
# 🚀 Crew: crew
# └── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
#     Assigned to: AI Researcher
#     Status: ✅ Completed
# ┌────────────────────────────── Task Completion ──────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: 34f21be0-64b8-4545-82fd-992dc669b9e5                                 │
# │  Agent: AI Researcher                                                       │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: Technical Writer
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
# ## Task: 위 조사 결과를 참고하여, 멀티 에이전트 시스템의 장점에 대한 짧은
# 결론을 작성하세요.
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
# .
#
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
# # Agent: Technical Writer
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
# ## Final Answer:
# 멀티 에이전트 시스템은 분산 처리와 확장성을 통해 작업 효율성을 극대화하며,
# 에이전트 간의 협력을 통해 신뢰성과 내결함성을 높입니다. 이러한 시스템은 다양한
# 문제를 함께 해결할 수 있게 설계되어, 복잡한 상황에서도 창의적이고 효율적인
# 결과를 도출할 수 있습니다. 결과적으로, 멀티 에이전트 시스템은 복잡한 문제
# 해결에 강점을 지닌 현대 정보 기술의 중요한 구성 요소로 자리잡고 있습니다.
#
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
# .
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Assigned to: Technical Writer
# 🚀 Crew: crew
# ├── 📋 Task: 34f21be0-64b8-4545-82fd-992dc669b9e5
# │   Assigned to: AI Researcher
# │   Status: ✅ Completed
# └── 📋 Task: 570b1fe9-6b63-4484-b5a8-03d62e5efa86
#     Assigned to: Technical Writer
#     Status: ✅ Completed
# ┌────────────────────────────── Task Completion ──────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: 570b1fe9-6b63-4484-b5a8-03d62e5efa86                                 │
# │  Agent: Technical Writer                                                    │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌────────────────────────────── Crew Completion ──────────────────────────────┐
# │                                                                             │
# │  Crew Execution Completed                                                   │
# │  Name: crew                                                                 │
# │  ID: 9c5bbe8e-fa04-4f99-8820-d5cbf7f4e4f6                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
#
# [Task 1 Output]
# - **분산 처리와 확장성**: 멀티 에이전트 시스템은 여러 개의 개별 에이전트가 독립적으로 작업을 수행할 수 있게 하기 때문에, 작업을 효율적으로 나눠 처리할 수 있습니다. 이 방식은 시스템의 확장성을 높여, 더 많은 에이전트를 추가함으로써 처리 능력을 쉽게 늘릴 수 있게 합니다.
#
# - **신뢰성 및 내결함성**: 여러 개의 에이전트가 서로 협력하며 작업을 수행하기 때문에, 하나의 에이전트가 실패하더라도 다른 에이전트들이 그 작업을 대체하거나 협력하여 시스템의 전체 기능이 감소하지 않습니다. 이로 인해 전체 시스템의 신뢰성과 내결함성이 향상됩니다.
#
# - **복잡한 문제 해결능력**: 멀티 에이전트 시스템은 다양한 개체들이 상호작용할 수 있도록 설계되어 복잡한 문제를 해결하는 데 효과적입니다. 에이전트들 간의 협업과 경쟁을 통해, 다양한 해결책을 모색할 수 있어 더 창의적이고 효율적인 결과를 도출할 수 있습니다.
#
#
# [Task 2 Output]
# 멀티 에이전트 시스템은 분산 처리와 확장성을 통해 작업 효율성을 극대화하며, 에이전트 간의 협력을 통해 신뢰성과 내결함성을 높입니다. 이러한 시스템은 다양한 문제를 함께 해결할 수 있게 설계되어, 복잡한 상황에서도 창의적이고 효율적인 결과를 도출할 수 있습니다. 결과적으로, 멀티 에이전트 시스템은 복잡한 문제 해결에 강점을 지닌 현대 정보 기술의 중요한 구성 요소로 자리잡고 있습니다.

# %%
# 단일 에이전트 (다양한 치환잔)
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os
from crewai import  Agent,task,Crew,Process

# .env 파일 업로드하여 환경변수 설정
load_dotenv()
# Out:
# True

# %%
# 여행 기획사 에이전트 정의
travel_agent = Agent(
    role='여행 기획자',
    goal='사용자의 요청에 따라 {place} 여행 일정을 계획하고 제안합니다.',
    backstory='여행사에서 10년 경력의 전문 여행 플래너로, 다양한 국내 여행 코스를 알고 있습니다.',
    verbose=False
)

# %%
# 부산 3일 여행 일정 작성 Task 정의
itinerary_task = Task(
    description=(
        "{place}에서 {days}일간 여행 일정을 계획해 주세요.\n"
        "{days}일을 1일차, 2일차와 같이 차수로 나누고, 각 일차 마다 아침/점심/저녁에 할 활동을 상세히 제안하세요.\n"
        "여행 일정에는 {place}의 주요 관광지와 현지 맛집 추천을 포함하고, 교통 수단 정보나 팁이 있으면 함께 제공하세요."
    ),
    agent=travel_agent,
    expected_output='{days}일을 Day 1, Day 2,...으로 구분된 상세 일정 제안'
)

# %%
# Crew 생성 및 실행(순차 실행-Task가 하나뿐이므로 순차 처리)
crew_single = Crew(
    agents=[travel_agent],
    tasks=[itinerary_task],
    process=Process.sequential,
    verbose=True
)

# %%
print('===[단일 에이전트] 부산 3일 일정 생성 시작===')
result_single = crew_single.kickoff(inputs={"place":"부산","days":3})
print("=== [단일 에이전트] 생성된 부산 3일 일정 ===")
print(result_single)
# Out:
# ===[단일 에이전트] 부산 3일 일정 생성 시작===
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 3325f6ad-c54c-4208-90ca-6ceee32b83f2                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: 여행 기획자
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
# ## Task: 부산에서 3일간 여행 일정을 계획해 주세요.
# 3일을 1일차, 2일차와 같이 차수로 나누고, 각 일차 마다 아침/점심/저녁에 할
# 활동을 상세히 제안하세요.
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
# 여행 일정에는 부산의 주요 관광지와 현지 맛집 추천을 포함하고, 교통 수단 정보나
# 팁이 있으면 함께 제공하세요.
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
# mExecuting Task...
#
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
# # Agent: 여행 기획자
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
# ## Final Answer:
# **부산 3일 여행 일정**
#
# ---
#
# ### **Day 1: 해운대와 광안리 탐방**
#
# - **아침**
#   - **장소**: 해운대 해수욕장
#   - **활동**: 해운대 해변에서 산책 후, 해운대 근처 '고고밥'에서 해물뚝배기
# 조식.
#   - **팁**: 해운대 해변은 자유롭게 걸을 수 있으며, 바다의 경치를 즐길 수
# 있습니다. 산책 후 신선한 해물로 가득한 아침식사를 즐겨보세요!
#
# - **점심**
#   - **장소**: 동백섬
#   - **활동**: 동백섬에서 아름다운 경치를 감상하고, 사진 촬영. 그 후 인근
# '청사포'에서 신선한 회를 점심으로 추천합니다.
#   - **교통수단**: 1001번 버스를 타고 동백섬으로 이동.
#   - **팁**: 청사포 근처의 바다 쪽 회집에서 회를 즐기면 좋습니다.
#
# - **저녁**
#   - **장소**: 광안리 해수욕장
#   - **활동**: 저녁에는 광안리 해변에서 석양을 감상하며, 카페 '카페 드림'에서
# 커피 또는 디저트를 즐깁니다.
#   - **식사**: '광안리 회센터'에서 석쇠구이 또는 생선구이를 추천합니다.
#   - **팁**: 광안리 해변은 야경이 아름답고, 다양한 노점상이 있어 저녁식사 후
# 산책하기에 좋습니다.
#
# ---
#
# ### **Day 2: 문화와 역사 체험**
#
# - **아침**
#   - **장소**: 범어사
#   - **활동**: 범어사에서 아침 명상을 하며 고요함을 느껴보세요.
#   - **식사**: 범어사 근처의 '전통 시골밥상'에서 비빔밥으로 아침 식사를
# 즐기세요.
#   - **팁**: 범어사에서의 산책은 전통적인 건축과 자연을 동시에 즐길 수 있습니다.
#
# - **점심**
#   - **장소**: 자갈치 시장
#   - **활동**: 자갈치 시장에서 다양한 해산물을 구경 후, 간단한 점심으로 생선회나
# 조개구이를 추천합니다.
#   - **교통수단**: 지하철 1호선을 타고 자갈치역 하차.
#   - **팁**: 지역 주민이 추천하는 노점에서 먹어보는 것도 좋은 경험입니다.
#
# - **저녁**
#   - **장소**: 부산타워
#   - **활동**: 저녁에는 부산타워로 올라가 부산 시내의 전경을 감상합니다.
#   - **식사**: 타워 인근의 '동백아구찜'에서 아구찜을 시켜보세요.
#   - **팁**: 부산타워의 전망대는 입장료가 있으니 미리 체크하고 가세요.
#
# ---
#
# ### **Day 3: 자연과 레저 활동**
#
# - **아침**
#   - **장소**: 송정 해수욕장
#   - **활동**: 송정 해수욕장에서 서핑 체험(서핑 강습 예약 필수) 후 근처의 '송정
# 수산물 식당'에서 조식을 즐깁니다.
#   - **팁**: 송정은 조용하고 여유로운 분위기에서 서핑을 즐기기 좋은 장소입니다.
#
# - **점심**
#   - **장소**: 태종대
#   - **활동**: 태종대의 아름다운 해안 절벽을 감상하며 하이킹을 즐깁니다. 점심은
# '태종대 원조 갈비찜'에서 돼지 갈비찜으로 추천합니다.
#   - **교통수단**: 1011번 버스를 타고 태종대로 이동.
#   - **팁**: 태종대 입구에서 전망대까지의 경치가 매우 아름답습니다. 카메라는
# 필수!
#
# - **저녁**
#   - **장소**: 남포동
#   - **활동**: 남포동 거리에서 야경을 즐기며 쇼핑 및 거리음식을 탐방합니다.
#   - **식사**: '남포동 돼지국밥'에서 부산의 전통적인 느낌을 주는 돼지국밥을
# 저녁으로 추천합니다.
#   - **팁**: 남포동 지역은 다양한 먹거리가 있으니 여러 곳을 둘러보며 먹어보세요.
#
# ---
#
# 부산은 대중교통이 좋아 버스와 지하철을 이용해 쉽게 이동할 수 있습니다. 버스
# 노선이나 지하철 시간표는 스마트폰 앱을 통해 확인할 수 있습니다. 추가로 여행 중
# 현지의 맛집과 카페를 스스로 발견하는 것도 좋은 경험이니, 그 때 그 때의 기분에
# 따라 일정을 조금 더 자유롭게 조정하는 것도 추천합니다! 즐거운 부산 여행 되세요!
#
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
# mExecuting Task...
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Assigned to: 여행 기획자
# 🚀 Crew: crew
# └── 📋 Task: b81938d0-9432-418f-ba91-f94f58e1e135
#     Assigned to: 여행 기획자
#     Status: ✅ Completed
# ┌────────────────────────────── Task Completion ──────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: b81938d0-9432-418f-ba91-f94f58e1e135                                 │
# │  Agent: 여행 기획자                                                         │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌────────────────────────────── Crew Completion ──────────────────────────────┐
# │                                                                             │
# │  Crew Execution Completed                                                   │
# │  Name: crew                                                                 │
# │  ID: 3325f6ad-c54c-4208-90ca-6ceee32b83f2                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# === [단일 에이전트] 생성된 부산 3일 일정 ===
# **부산 3일 여행 일정**
#
# ---
#
# ### **Day 1: 해운대와 광안리 탐방**
#
# - **아침**
#   - **장소**: 해운대 해수욕장
#   - **활동**: 해운대 해변에서 산책 후, 해운대 근처 '고고밥'에서 해물뚝배기 조식.
#   - **팁**: 해운대 해변은 자유롭게 걸을 수 있으며, 바다의 경치를 즐길 수 있습니다. 산책 후 신선한 해물로 가득한 아침식사를 즐겨보세요!
#
# - **점심**
#   - **장소**: 동백섬
#   - **활동**: 동백섬에서 아름다운 경치를 감상하고, 사진 촬영. 그 후 인근 '청사포'에서 신선한 회를 점심으로 추천합니다.
#   - **교통수단**: 1001번 버스를 타고 동백섬으로 이동.
#   - **팁**: 청사포 근처의 바다 쪽 회집에서 회를 즐기면 좋습니다.
#
# - **저녁**
#   - **장소**: 광안리 해수욕장
#   - **활동**: 저녁에는 광안리 해변에서 석양을 감상하며, 카페 '카페 드림'에서 커피 또는 디저트를 즐깁니다.
#   - **식사**: '광안리 회센터'에서 석쇠구이 또는 생선구이를 추천합니다.
#   - **팁**: 광안리 해변은 야경이 아름답고, 다양한 노점상이 있어 저녁식사 후 산책하기에 좋습니다.
#
# ---
#
# ### **Day 2: 문화와 역사 체험**
#
# - **아침**
#   - **장소**: 범어사
#   - **활동**: 범어사에서 아침 명상을 하며 고요함을 느껴보세요.
#   - **식사**: 범어사 근처의 '전통 시골밥상'에서 비빔밥으로 아침 식사를 즐기세요.
#   - **팁**: 범어사에서의 산책은 전통적인 건축과 자연을 동시에 즐길 수 있습니다.
#
# - **점심**
#   - **장소**: 자갈치 시장
#   - **활동**: 자갈치 시장에서 다양한 해산물을 구경 후, 간단한 점심으로 생선회나 조개구이를 추천합니다.
#   - **교통수단**: 지하철 1호선을 타고 자갈치역 하차.
#   - **팁**: 지역 주민이 추천하는 노점에서 먹어보는 것도 좋은 경험입니다.
#
# - **저녁**
#   - **장소**: 부산타워
#   - **활동**: 저녁에는 부산타워로 올라가 부산 시내의 전경을 감상합니다.
#   - **식사**: 타워 인근의 '동백아구찜'에서 아구찜을 시켜보세요.
#   - **팁**: 부산타워의 전망대는 입장료가 있으니 미리 체크하고 가세요.
#
# ---
#
# ### **Day 3: 자연과 레저 활동**
#
# - **아침**
#   - **장소**: 송정 해수욕장
#   - **활동**: 송정 해수욕장에서 서핑 체험(서핑 강습 예약 필수) 후 근처의 '송정 수산물 식당'에서 조식을 즐깁니다.
#   - **팁**: 송정은 조용하고 여유로운 분위기에서 서핑을 즐기기 좋은 장소입니다.
#
# - **점심**
#   - **장소**: 태종대
#   - **활동**: 태종대의 아름다운 해안 절벽을 감상하며 하이킹을 즐깁니다. 점심은 '태종대 원조 갈비찜'에서 돼지 갈비찜으로 추천합니다.
#   - **교통수단**: 1011번 버스를 타고 태종대로 이동.
#   - **팁**: 태종대 입구에서 전망대까지의 경치가 매우 아름답습니다. 카메라는 필수!
#
# - **저녁**
#   - **장소**: 남포동
#   - **활동**: 남포동 거리에서 야경을 즐기며 쇼핑 및 거리음식을 탐방합니다.
#   - **식사**: '남포동 돼지국밥'에서 부산의 전통적인 느낌을 주는 돼지국밥을 저녁으로 추천합니다.
#   - **팁**: 남포동 지역은 다양한 먹거리가 있으니 여러 곳을 둘러보며 먹어보세요.
#
# ---
#
# 부산은 대중교통이 좋아 버스와 지하철을 이용해 쉽게 이동할 수 있습니다. 버스 노선이나 지하철 시간표는 스마트폰 앱을 통해 확인할 수 있습니다. 추가로 여행 중 현지의 맛집과 카페를 스스로 발견하는 것도 좋은 경험이니, 그 때 그 때의 기분에 따라 일정을 조금 더 자유롭게 조정하는 것도 추천합니다! 즐거운 부산 여행 되세요!

# %%
from crewai.tools import BaseTool
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os
from crewai import Agent, Task, Crew, Process

load_dotenv()
# Out:
# True

# %%
# 커스텀 웹 검색 도구 준비
class MyCustomDuckDuckGoTool(BaseTool):
    name:str='DuckDuckGo Search Tool'
    description:str = "웹에서 최신 정보를 검색할 수 있는 도구입니다."

    def _run(self,query:str) -> str:
        duckduckgo_tool = DuckDuckGoSearchRun()
        response = duckduckgo_tool.invoke(query)
        return response

# DuckDuckGo 검색 도구 인스턴스 생성
search_tool =  MyCustomDuckDuckGoTool()

# %%
# 정보 조사 에이전트 정의
research_agent=Agent(
    role='정보 조사자',
    goal='{place} 여행에 필요한 최신 정보를 조사하여 제공합니다',
    backstory='온라인 정보 검색에 능총한 여행 정보 전문가입니다.',
    tools=[search_tool], # 웹 검색 도구 장착
    verbose=True
)

# 일정 작성 에이전트 정의
planner_agent=Agent(
    role='여행 일정 기획자',
    goal='제공된 정보를 활용해 완성도 높은 {place} 여행 일정을 작성합니다.',
    backstory='국내 여행 일정을 여러 차례 기획한 경험이 풍부한 전문가입니다.',
    verbose=True
)

# %%
# 정보 조사 Task 정의
research_task = Task(
    description=(
        '{place} 여행을 위해 알아야 할 핵심 정보를 조사하세요.\n'
        '{place}의 인기 관광지 목록, 지역별 맛집 추천, 이동 시 유용한 교통 정보 등을 최신 자료를 기반으로 정리해 주세요'
    ),
    agent=research_agent,
    expected_output='한국어로 작성된 {place} 여행에 대한 요약 정보 목록'
)

# 일정 작성 Task 정의(이전 Task 결과를 context로 활용)
planning_task = Task(
    description=(
         "위의 조사 결과를 참고하여 {place}에서 {days}일 동안 머무는 여행 일정을 작성해 주세요.\n"
        "각 날짜별로 오전/오후/저녁 계획을 세우고, 조사된 관광지와 맛집 정보를 일정에 반영하세요.\n"
        "일정에는 방문지에 대한 간단한 설명이나 여행 팁도 포함해 주세요."
    ),
    agent=planner_agent,
    context=[research_task], # 이전 조사 결과를 컨텍스트로 전달
    expected_output='한국어로 작성된 조사된 정보를 반영한{days}일간의 여행 일정'
)

# %%
# 두 에이전트를 Crew로 묶어 순차 실행
crew_multi = Crew(
    agents=[research_agent,planner_agent],
    tasks=[research_task,planning_task],
    process=Process.sequential,
    verbose=True
)
print("\n=== [협업 에이전트] 부산 3일 일정 생성 시작 ===")
result_multi = crew_multi.kickoff(inputs={"place": "부산", "days": 3})
print("=== [협업 에이전트] 생성된 부산 3일 일정 ===")
print(result_multi)
# Out:
# === [협업 에이전트] 부산 3일 일정 생성 시작 ===
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 274cbbc0-6e22-48e9-bb3f-0e7c1df45513                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: 정보 조사자
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# ## Task: 부산 여행을 위해 알아야 할 핵심 정보를 조사하세요.
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# 부산의 인기 관광지 목록, 지역별 맛집 추천, 이동 시 유용한 교통 정보 등을 최신
# 자료를 기반으로 정리해 주세요
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# sing DuckDuckGo Search Tool (1)
#
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# # Agent: 정보 조사자
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# ## Thought: Thought: 부산 여행에 필요한 핵심 정보를 조사해야 한다.
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# ## Using tool: DuckDuckGo Search Tool
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# ## Tool Input: ol (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# "{\"query\": \"\\ubd80\\uc0b0 \\uc5ec\\ud589 \\ud544\\uc218 \\uc815\\ubcf4
# \\uc778\\uae30 \\uad00\\uad11\\uc9c0 \\ub9db\\uc9d1 \\ucd94\\ucc9c
# \\uad50\\ud1b5 \\uc815\\ubcf4 2023\"}"
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# ## Tool Output: l (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 이번 글에서는 부산의 필수 여행 코스, 맛집, 교통편, 숙박, 최적의 여행 시기, 여행
# 팁 까지 상세히 정리했다. 1. 부산 필수 여행 코스 추천. 부산은 해변, 전통시장,
# 전망대, 힙한 감성 카페까지 다채로운 관광지가 많아 취향에 맞춰 여행을 계획할 수
# 있다. 🚗 TIP: 부산의 여행지는 대부분 해안가를 따라 분포하므로, 일정에 따라 해변
# 중심 또는 도심 중심으로 코스를 나누면 효율적이다. 2. 부산 추천 여행 일정 (2박
# 3일 기준) 부산은 2박 3일 일정으로도 충분히 주요 명소를 둘러볼 수 있으며, 여유가
# 있다면 3박 4일 코스로 근교까지 포함할 수도 있다. 부산은 한국에서 두 번째로 큰
# 도시로, 아름다운 해변과 다양한 관광 명소로 유명하죠!😄 이번 글에서는 주나조아의
# 고향이기도 한 부산에서 꼭 가봐야 할 명소, 추천 맛집, 그리고 효율적인 교통편
# 정보를 상세히 소개해 드리겠습니다.😄🌊 해운대 해수욕장 ... 부산은 대중교통이 잘
# 발달되어 있어 여행하기 편리해요! 지하철, 버스, 택시, 그리고 다양한 교통수단을
# 활용하면 더욱 알찬 여행이 될 거예요. 🚍🚋. ️ 교통카드 (T-money, 캐시비) 사용:
# 지하철과 버스를 환승할 때 할인 적용. ️ 부산 시티투어 버스: 주요 관광지를
# 순환하는 버스로 하루권 이용 가능. ️ 지하철 1일권: 하루 동안 무제한 이용 가능
# (₩5,000) 부산 : 필수 여행 코스 & 맛집 추천대한민국 제2의 도시이자 대표적인 항구
# 도시인 부산은 아름다운 해변, 다양한 먹거리, 풍부한 문화 유산이 어우러진
# 여행지입니다. 해운대와 광안리 같은 해변 명소부터 감천문화마을, 자갈치시장 같은
# 독특한 장소까지, 여행자에게 잊지 못할 추억을 선사합니다. 부산은 매력적인 해변과
# 문화가 어우러진 도시로, 관광객들에게 다양한 즐길 거리를 제공합니다. 오늘은
# 현지인 추천으로 부산에서 꼭 가봐야 할 필수 관광 코스 를 소개할게요! 🌅. 부산의
# 대표적인 해변인 해운대 해수욕장은 푸른 바다와 곱슬한 모래사장이 매력 을
# 자랑합니다. 여름에는 해변에서 시원한 물놀이를 즐길 수 있을 뿐만 아니라, 바다
# 전망의 카페와 맛집도 다양하게 즐길 수 있어요. 특히 해질 무렵의 뷰는 환상적 이니
# 꼭 놓치지 마세요! 🏖️. "부산의 해운대는 여름의 성지입니다!" — 현지인들의 팁.
# 부산의 격조 높은 야경을 감상하고 싶다면 광안대교 드라이브 는 필수 코스입니다.
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
#     ├── 🔧 Used DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# sed DuckDuckGo Search Tool (1)
#
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# # Agent: 정보 조사자
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# ## Final Answer:  (1)
# 부산 여행에 필요한 핵심 정보 목록:
#
# 1. **부산 필수 여행 코스 추천**
#    - 해운대 해수욕장: 푸른 바다와 곱슬한 모래사장이 매력, 여름에는 물놀이와
# 바다 전망 카페 즐길 수 있음.
#    - 광안리 해수욕장: 해변과 광안대교의 아름다운 야경을 즐길 수 있음.
#    - 감천문화마을: 독특한 거리 풍경과 벽화가 있는 예술 마을.
#    - 자갈치 시장: 신선한 해산물을 즐길 수 있는 전통 시장.
#
# 2. **부산 추천 여행 일정 (2박 3일 기준)**
#    - 1일차: 해운대 해수욕장, 동백섬, 광안리 해수욕장.
#    - 2일차: 감천문화마을, 자갈치 시장, 국제시장.
#    - 3일차: 부산타워, 남포동, 용두산 공원.
#
# 3. **맛집 추천**
#    - 해운대: 구포 아저씨 냉면, 밀면.
#    - 남포동: 할매국수, 부산 곰장어.
#    - 자갈치: 원조 자갈치 생선회.
#
# 4. **교통 정보**
#    - 대중교통이 발달되어 있음: 지하철, 버스, 택시를 이용하여 편리하게 이동
# 가능.
#    - 교통카드 사용 (T-money, 캐시비): 대중교통 환승 할인 적용.
#    - 부산 시티투어 버스: 주요 관광지를 순환하는 하루권 가능.
#    - 지하철 1일권: 하루 동안 무제한 이용 가능 (₩5,000).
#
# 5. **여행 팁**
#    - 해양 스포츠와 다양한 해변 활동을 즐기려면 여름에 방문.
#    - 겨울철에는 해운대 주변의 온천과 스파를 즐기기 좋음.
#    - 야경 감상을 원한다면 저녁 시간에 광안대교 드라이브 추천.
#
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# sed DuckDuckGo Search Tool (1)
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Assigned to: 정보 조사자
#     Status: ✅ Completed
# 🚀 Crew: crew
# └── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
#     Assigned to: 정보 조사자
#     Status: ✅ Completed
#     └── 🔧 Used DuckDuckGo Search Tool (1)
# ┌────────────────────────────── Task Completion ──────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: 073d78d7-f0af-4c0f-8437-6b247c91c1c5                                 │
# │  Agent: 정보 조사자                                                         │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# # Agent: 여행 일정 기획자
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
# ## Task: 위의 조사 결과를 참고하여 부산에서 3일 동안 머무는 여행 일정을 작성해
# 주세요.
# 각 날짜별로 오전/오후/저녁 계획을 세우고, 조사된 관광지와 맛집 정보를 일정에
# 반영하세요.
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
# 일정에는 방문지에 대한 간단한 설명이나 여행 팁도 포함해 주세요.
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#
#
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
# # Agent: 여행 일정 기획자
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
# ## Final Answer:
# **부산 3일 여행 일정**
#
# **1일차: 해운대 & 광안리 해수욕장 탐방**
# - **오전**
#   - **해운대 해수욕장**: 부산 여행의 시작은 해운대 해수욕장에서! 푸른 바다와
# 고운 모래사장을 즐길 수 있으며, 여름에는 물놀이와 바다 전망의 카페에서 휴식을
# 취할 수 있습니다.
#   - **맛집 추천**: 해운대에서 제공하는 ‘구포 아저씨 냉면’이나 ‘밀면’을
# 맛보세요.
#
# - **오후**
#   - **동백섬**: 해운대 해수욕장에서 한참 걷다 보면 동백섬이 나옵니다. 아름다운
# 자연과 함께 해안 산책로를 즐길 수 있으며, 마린 시티의 멋진 경관을 감상할 수
# 있습니다.
#   - **광안리 해수욕장으로 이동**: 광안리 해수욕장까지 이동하여 해변에서
# 여유로운 시간을 보내세요.
#
# - **저녁**
#   - **광안대교 야경 감상**: 저녁이 되면 아름다운 광안대교의 야경을 감상할 수
# 있습니다. 하늘이 어두워질 때 조명을 받는 다리의 모습은 인상적입니다.
#   - **디너**: 광안리 주변에서 해양 음식과 함께 저녁을 즐길 수 있는 레스토랑을
# 찾아보세요.
#
# ---
#
# **2일차: 감천문화마을 & 자갈치 시장 탐방**
# - **오전**
#   - **감천문화마을**: 아침에는 감천문화마을을 방문해 보세요. 벽화와 독특한
# 건축물들이 아름답고 예술적인 사진 촬영지입니다. 마을을 탐방하며 예술적 감성을
# 느낄 수 있습니다.
#
# - **오후**
#   - **자갈치 시장**: 점심 시간에 자갈치 시장으로 이동하여 신선한 해산물을
# 즐겨보세요. 이곳은 부산의 대표적인 해산물 시장으로, '원조 자갈치 생선회'를 맛볼
# 수 있습니다.
#   - **국제시장**: 자갈치 시장에서 가까운 국제시장도 방문할 수 있으며, 다양한
# 상품과 길거리 음식을 경험할 수 있습니다.
#
# - **저녁**
#   - **남포동 방문**: 저녁에는 남포동으로 이동하여 ‘할매국수’에서 전통 국수를
# 맛보세요.
#   - 지역의 멋진 야경도 함께 즐길 수 있습니다.
#
# ---
#
# **3일차: 부산타워 & 용두산 공원 탐방**
# - **오전**
#   - **부산타워 방문**: 이른 아침 부산타워에 올라가 대관람차에서 부산 시내를
# 한눈에 내려다보세요. 타워 주변의 공원에서 산책하는 것도 좋습니다.
#
# - **오후**
#   - **용두산 공원 산책**: 부산타워 근처인 용두산 공원에서 자연을 느끼며
# 산책해보세요. 기념사진을 남기기 좋은 포토존도 많습니다.
#
# - **저녁**
#   - 부산 여행의 마무리는 다시 남포동으로 돌아가서 다양한 부산 음식을 즐기는
# 것입니다. '부산 곰장어'를 전문으로 하는 식당에서 저녁을 마무리하면 좋습니다.
#
# ---
#
# **여행 팁**
# - 대중교통이 잘 발달되어 있으므로, 지하철과 버스를 활용해도 좋습니다.
# 교통카드인 T-money를 구입하여 사용하면 편리하게 이동할 수 있습니다.
# - 부산 시티투어 버스를 이용하면 주요 관광지를 편리하게 둘러볼 수 있으며,
# 하루권을 추천합니다.
# - 해양 스포츠와 다양한 해변 활동은 여름에 방문할 때 즐기기 좋으며, 겨울에는
# 해운대 주변의 온천과 스파에서 여유로운 시간을 보내세요.
#
# 부산에서의 멋진 여행이 되길 바랍니다!
#
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Assigned to: 여행 일정 기획자
# 🚀 Crew: crew
# ├── 📋 Task: 073d78d7-f0af-4c0f-8437-6b247c91c1c5
# │   Assigned to: 정보 조사자
# │   Status: ✅ Completed
# │   └── 🔧 Used DuckDuckGo Search Tool (1)
# └── 📋 Task: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54
#     Assigned to: 여행 일정 기획자
#     Status: ✅ Completed
# ┌────────────────────────────── Task Completion ──────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: 8b7ca8c5-e224-4390-9e5d-2a6be48aca54                                 │
# │  Agent: 여행 일정 기획자                                                    │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌────────────────────────────── Crew Completion ──────────────────────────────┐
# │                                                                             │
# │  Crew Execution Completed                                                   │
# │  Name: crew                                                                 │
# │  ID: 274cbbc0-6e22-48e9-bb3f-0e7c1df45513                                   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# === [협업 에이전트] 생성된 부산 3일 일정 ===
# **부산 3일 여행 일정**
#
# **1일차: 해운대 & 광안리 해수욕장 탐방**
# - **오전**
#   - **해운대 해수욕장**: 부산 여행의 시작은 해운대 해수욕장에서! 푸른 바다와 고운 모래사장을 즐길 수 있으며, 여름에는 물놀이와 바다 전망의 카페에서 휴식을 취할 수 있습니다.
#   - **맛집 추천**: 해운대에서 제공하는 ‘구포 아저씨 냉면’이나 ‘밀면’을 맛보세요.
#
# - **오후**
#   - **동백섬**: 해운대 해수욕장에서 한참 걷다 보면 동백섬이 나옵니다. 아름다운 자연과 함께 해안 산책로를 즐길 수 있으며, 마린 시티의 멋진 경관을 감상할 수 있습니다.
#   - **광안리 해수욕장으로 이동**: 광안리 해수욕장까지 이동하여 해변에서 여유로운 시간을 보내세요.
#
# - **저녁**
#   - **광안대교 야경 감상**: 저녁이 되면 아름다운 광안대교의 야경을 감상할 수 있습니다. 하늘이 어두워질 때 조명을 받는 다리의 모습은 인상적입니다.
#   - **디너**: 광안리 주변에서 해양 음식과 함께 저녁을 즐길 수 있는 레스토랑을 찾아보세요.
#
# ---
#
# **2일차: 감천문화마을 & 자갈치 시장 탐방**
# - **오전**
#   - **감천문화마을**: 아침에는 감천문화마을을 방문해 보세요. 벽화와 독특한 건축물들이 아름답고 예술적인 사진 촬영지입니다. 마을을 탐방하며 예술적 감성을 느낄 수 있습니다.
#
# - **오후**
#   - **자갈치 시장**: 점심 시간에 자갈치 시장으로 이동하여 신선한 해산물을 즐겨보세요. 이곳은 부산의 대표적인 해산물 시장으로, '원조 자갈치 생선회'를 맛볼 수 있습니다.
#   - **국제시장**: 자갈치 시장에서 가까운 국제시장도 방문할 수 있으며, 다양한 상품과 길거리 음식을 경험할 수 있습니다.
#
# - **저녁**
#   - **남포동 방문**: 저녁에는 남포동으로 이동하여 ‘할매국수’에서 전통 국수를 맛보세요.
#   - 지역의 멋진 야경도 함께 즐길 수 있습니다.
#
# ---
#
# **3일차: 부산타워 & 용두산 공원 탐방**
# - **오전**
#   - **부산타워 방문**: 이른 아침 부산타워에 올라가 대관람차에서 부산 시내를 한눈에 내려다보세요. 타워 주변의 공원에서 산책하는 것도 좋습니다.
#
# - **오후**
#   - **용두산 공원 산책**: 부산타워 근처인 용두산 공원에서 자연을 느끼며 산책해보세요. 기념사진을 남기기 좋은 포토존도 많습니다.
#
# - **저녁**
#   - 부산 여행의 마무리는 다시 남포동으로 돌아가서 다양한 부산 음식을 즐기는 것입니다. '부산 곰장어'를 전문으로 하는 식당에서 저녁을 마무리하면 좋습니다.
#
# ---
#
# **여행 팁**
# - 대중교통이 잘 발달되어 있으므로, 지하철과 버스를 활용해도 좋습니다. 교통카드인 T-money를 구입하여 사용하면 편리하게 이동할 수 있습니다.
# - 부산 시티투어 버스를 이용하면 주요 관광지를 편리하게 둘러볼 수 있으며, 하루권을 추천합니다.
# - 해양 스포츠와 다양한 해변 활동은 여름에 방문할 때 즐기기 좋으며, 겨울에는 해운대 주변의 온천과 스파에서 여유로운 시간을 보내세요.
#
# 부산에서의 멋진 여행이 되길 바랍니다!

# %%
# 개선된 일정 작성 Task 정의(예산 및 교통 고려 추가)
imporved_planning_task = Task(
    description=(
        "위의 조사 결과를 참고하여 부산에서 3일 동안 머무는 여행 일정을 작성해 주세요.\n"
        "각 날짜별로 오전/오후/저녁 계획을 세우고, 조사된 관광지와 맛집 정보를 일정에 반영하세요.\n"
        "가능하면 예산은 하루 10만원 내외로 맞추고, 이동은 모두 대중교통 을 이용하는 것으로 고려하세요.\n"
        "버스정류장 및 지하철역을 포함한 대중교통 경로를 제안해 주세요.\n"
        "버스 및 지하철을 이용할 때의 소요 시간도 포함해 주세요.\n"
        "일정에는 방문지에 대한 간단한 설명이나 여행 팁도 포함해 주세요. 결과는 한국어로 작성해 주세요.\n"
    ),
    agent=planner_agent,
    context=[research_task],
    expected_output="예산과 교통을 고려한 3일간의 여행 일정"
)

# %%
from agent_tools import DuckDuckGoSearchTool, WebScraperTool, CalculatorTool
from crewai import Agent, Task, Crew, Process
# 도구 인스턴스 생성
search_tool = DuckDuckGoSearchTool()
scrape_tool = WebScraperTool()
calculator_tool = CalculatorTool()
news_agent = Agent(
    role="뉴스 분석가",
    goal="최신 뉴스를 검색하여 요약",
    backstory="뉴스 분석 전문 AI 기자",
    tools=[search_tool, scrape_tool],
    verbose=False
)
news_task = Task(
    description="최근 인공지능 관련 뉴스 3건을 요약하고 링크 제공",
    expected_output="한국어로 작성된 뉴스 3건의 요약 및 링크",
    agent=news_agent
)
crew = Crew(
    agents=[news_agent],
    tasks=[news_task],
    process=Process.sequential,
    verbose=False
)
result = crew.kickoff()
print(result)
# Out:
# c:\Users\main\miniconda3\envs\streamlit_env\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:48: UserWarning: backend='api' is deprecated, using backend='auto'
#   ddgs_gen = ddgs.text(
# c:\Users\main\miniconda3\envs\streamlit_env\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:48: UserWarning: backend='api' is deprecated, using backend='auto'
#   ddgs_gen = ddgs.text(
# c:\Users\main\miniconda3\envs\streamlit_env\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:48: UserWarning: backend='api' is deprecated, using backend='auto'
#   ddgs_gen = ddgs.text(
# c:\Users\main\miniconda3\envs\streamlit_env\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:48: UserWarning: backend='api' is deprecated, using backend='auto'
#   ddgs_gen = ddgs.text(
# c:\Users\main\miniconda3\envs\streamlit_env\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:48: UserWarning: backend='api' is deprecated, using backend='auto'
#   ddgs_gen = ddgs.text(
# 최근 인공지능 관련 뉴스 3건과 링크는 다음과 같습니다:
#
# 1. **오픈AI, GPT-5 개발 본격 착수**
#    - 오픈AI는 차세대 언어모델인 GPT-5 개발을 공식적으로 발표했습니다. 이 모델은 더 향상된 자연어 처리 능력과 고도화된 학습 알고리즘을 통해 다양한 산업에서 응용될 것으로 기대되고 있습니다.
#    - [링크](https://example.com/1)
#
# 2. **구글 딥마인드, 신경망 기반 약물 개발 성공**
#    - 구글 딥마인은 인공지능을 활용하여 신약 후보 물질을 단기간에 개발하는 데 성공했습니다. 이는 기존의 약물 개발 과정을 혁신적으로 단축할 것으로 보입니다.
#    - [링크](https://example.com/2)
#
# 3. **AI 기본법 통과**
#    - 한국 국회에서 인공지능 기본법이 통과되었습니다. 이 법안은 AI 기술의 발전과 관련된 다양한 법적 기준을 제시하고 있으며, 산업 전반에 걸쳐 AI의 안전한 도입과 활용을 도모하고자 합니다.
#    - [링크](https://example.com/3)

# %%
from agent_tools import DuckDuckGoSearchTool, WebScraperTool, CalculatorTool
from crewai import Agent, Task, Crew, Process
# 도구 인스턴스 생성
search_tool = DuckDuckGoSearchTool()
scrape_tool = WebScraperTool()
calculator_tool = CalculatorTool()
recipe_agent = Agent(
role="요리 분석가",
    goal="요리 레시피 추천 및 요약",
    backstory="글로벌 요리 전문 AI 셰프",
    tools=[search_tool, scrape_tool],
    verbose=False
)
recipe_task = Task(
    description="채식 파스타 레시피 추천, 재료 및 조리법 안내",
    expected_output="한국어로 작성된 채식 파스타 레시피(재료 및 조리법)",
    agent=recipe_agent
)
crew = Crew(
    agents=[recipe_agent],
    tasks=[recipe_task],
    process=Process.sequential,
    verbose=False
)
result = crew.kickoff()
print(result)
# Out:
# c:\Users\main\miniconda3\envs\streamlit_env\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:48: UserWarning: backend='api' is deprecated, using backend='auto'
#   ddgs_gen = ddgs.text(
# 채식 파스타 레시피:
#
# 재료:
# - 파스타 면 50g
# - 냉동 새우 4~5개 (선택 사항)
# - 다진 마늘 1T
# - 소금 (물 1L에 소금 1t)
# - 각종 야채 (시금치, 버섯, 양파 등)
# - 방울 토마토, 파프리카 또는 피망, 브로콜리 (선택 사항)
# - 치즈 (선택 사항)
# - 기타 양념 (통후추, 파슬리 등)
#
# 조리법:
# 1. 물을 끓이면서 소금을 넣고, 파스타 면을 제품에 표기된 시간만큼 삶아 주세요.
# 2. 파스타 타이머가 2~3분 남았을 때 냉동 새우를 넣고 같이 삶아주세요.
# 3. 삶은 파스타와 새우는 체반에 담아 물기를 빼고, 물로 헹구거나 오일 코팅은 하지 마세요.
# 4. 다진 마늘을 준비 후, 필요한 경우 추가 재료를 준비합니다 (채소 및 토핑).
# 5. 모든 재료를 혼합하여 드레싱과 고소한 맛을 추가하세요.
# 6. 접시에 담고 원하는 방식으로 토핑이나 양념을 더합니다.
#
# 특별한 한 끼로 채식 파스타를 즐겨 보세요!

# %%
from agent_tools import DuckDuckGoSearchTool, WebScraperTool, CalculatorTool
from crewai import Agent, Task, Crew, Process
# 도구 인스턴스 생성
search_tool = DuckDuckGoSearchTool()
scrape_tool = WebScraperTool()
calculator_tool = CalculatorTool()
travel_agent = Agent(
role="여행 전문가",
    goal="최적의 여행 일정과 예산 계획 제공",
    backstory="다년간의 여행 플래너 경험 보유",
    tools=[search_tool, scrape_tool, calculator_tool],
    verbose=False
)
travel_task = Task(
    description="파리 5일 여행 일정(문화, 미식 포함), 예산은 1000달러 (항공 300달러, 숙박 하루 100달러).",
    expected_output="한국어로 작성된 5일간 파리 여행에 대한 상세한 일정과 예산 계산 결과",
    agent=travel_agent
)
crew = Crew(
    agents=[travel_agent],
    tasks=[travel_task],
    process=Process.sequential,
    verbose=False
)
result = crew.kickoff()
print(result)
# Out:
# c:\Users\main\miniconda3\envs\streamlit_env\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:48: UserWarning: backend='api' is deprecated, using backend='auto'
#   ddgs_gen = ddgs.text(
# ### 파리 5일 여행 일정 및 예산 계획
#
# **여행 기간:** 5일
# **총 예산:** 1000달러
# - **항공료:** 300달러
# - **숙박비:** 4박 x 100달러 = 400달러
# - **남은 예산:** 1000 - 700 = 300달러 (식사 및 교통비 포함)
#
# ---
#
# #### **1일 차: 파리 도착 및 주요 명소 탐방**
# - **오후:** 파리 도착 후 호텔 체크인
# - **저녁:** 에펠탑 방문 (야경 감상 및 조명 쇼)
# - **식사:** 에펠탑 근처 뷔페 레스토랑 (약 30달러)
#
# #### **2일 차: 문화체험의 날**
# - **오전:** 루브르 박물관 관람
#   - 티켓 예약: 20달러
# - **점심:** 박물관 근처의 카페 (약 20달러)
# - **오후:** 오르세 미술관 방문
#   - 티켓 예약: 15달러
# - **저녁:** 근처 프랑스 레스토랑에서 저녁 (약 50달러, 미식 경험)
#
# #### **3일 차: 역사 탐방 및 베르사유 궁전**
# - **오전:** 베르사유 궁전 방문
#   - 왕궁 입장권: 30달러
#   - 왕궁 내부 투어 (가이드 포함): 40달러
# - **점심:** 궁전 근처 레스토랑 (약 25달러)
# - **오후:** 몽마르트 언덕 탐방 및 성심성당 방문
# - **저녁:** 몽마르트 지역의 바에서 저녁 (약 40달러)
#
# #### **4일 차: 세느강 크루즈 및 자유 탐방**
# - **오전:** 센 강 주변 산책 및 세느강 크루즈 예약 (약 20달러)
# - **점심:** 강변 카페에서 식사 (약 20달러)
# - **오후:** 튈르리 정원 및 개선문 방문
# - **저녁:** 샹젤리제 거리의 유명한 카페 (약 50달러)
#
# #### **5일 차: 여유로운 하루 및 출국**
# - **오전:** 마지막 쇼핑 및 기념품 구매
# - **점심:** 파리 전통 음식 체험 (약 30달러)
# - **오후:** 공항으로 이동 및 출국
#
# ---
#
# ### 총 비용 계획
# - **식사 비용:** 약 300달러 (5일 동안)
# - **교통비:** 대중교통 이용 (약 50달러)
#
# **총 예상 비용:** 약 1000달러 (항공비, 숙박비 포함)
#
# 이렇게 구성된 일정으로 파리에서 멋진 5일을 보낼 수 있을 것입니다. 문의 사항이나 추가적인 계획이 필요하면 알려주세요!

# %%
from crewai import Agent,Task,Crew,Process
from agent_tools import DuckDuckGoSearchTool,WebScraperTool,CalculatorTool

search_tool=DuckDuckGoSearchTool()
scrape_tool=WebScraperTool()
calculator_tool=CalculatorTool()

planner_agent = Agent(
    role="총괄 여행 플래너",
    goal="최적의 서울 근교 1박 2일 여행 일정과 추천 음식을 종합하여 최종 여행 계획서를 작성",
    backstory="10년 경력의 베테랑 여행 컨설턴트로 다양한 분야의 의견을 취합하여 여행 계획을 완성합니다.",
    allow_delegation=True, # 다른 에이전트에게 업무 위임을 허용
    verbose=False
)

# %%
# 여행 전문가 Agent (여행 일정 추천 담당)
travel_agent = Agent(
    role="여행 전문가",
    goal="최신 여행 트렌드를 조사하여 서울 근교의 인기 있는 여행지와 일정을 제안",
    backstory="국내 여행지에 대해 잘 알고 있는 전문가로, 최근의 여행 트렌드를 바탕으로 관광지를 추천합니다.",
    tools=[search_tool],
    verbose= False
)
# 요리 전문가 Agent (음식 추천 담당)
culinary_agent = Agent(
    role="요리 전문가",
    goal="추천된 여행지와 잘 어울리는 현지 음식 및 레시피를 추천",
    backstory="국내 각 지역의 음식 문화와 레시피에 능통한 전문가로, 여행지에 어울리는 음식을 추천합니다.",
    tools=[search_tool],
    verbose= False
)

# %%
# Task 정의 (총괄 플래너에게 최종 여행 계획서 작성 지시)
planner_task = Task(
    description=(
        "국내 최신 여행 트렌드가 반영된 서울 근교의 1박 2일 여행 일정을 작성하고, "
        "각 여행지와 잘 어울리는 현지 음식과 레시피를 포함하여 여행 계획서를 한국어로 작성해주세요."
    ),
    expected_output=(
        "최신 여행 트렌드를 반영한 서울 근교 1박 2일 여행 일정과 "
        "각 여행지의 현지 음식 및 간단한 레시피를 포함한 한국어 여행 계획서"
    ),
    agent=planner_agent
)

# %%
# Crew 구성 (계층적 프로세스 사용)
crew = Crew(
    agents=[travel_agent, culinary_agent], # 하위 실행에 참여할 에이전트들 (관리자 제외)
    tasks=[planner_task],
    process=Process.hierarchical,
    manager_agent=planner_agent, # 총괄 여행 플래너를 매니저로 지정
)
# Crew 실행
if __name__ == "__main__":
    result = crew.kickoff()
    print("\n\n 최종 여행 계획서:\n")
    print(result)
# Out:
#  최종 여행 계획서:
#
# ### 서울 근교 1박 2일 여행 계획서
#
# **일정 개요:**
# - **목적지:** 경기도 가평 & 남양주
# - **일정:** 1박 2일
# - **주요 테마:** 자연과 문화, 지역 음식 체험
#
# ---
#
# #### **1일차: 가평**
#
# **07:00 - 출발**
# 서울에서 가평으로 출발 (약 1시간 30분 소요)
#
# **09:00 - 청평호 수족관 방문**
# - 청평호의 아름다운 풍경과 함께 다양한 수족관을 관람하며 자연을 만끽합니다.
#
# **11:30 - 점심**
# - **추천 음식:** 닭갈비
#   - **조리법:**
#     1. 닭고기를 적당한 크기로 자르고, 양념(고춧가루, 간장, 마늘, 생강, 설탕 등)으로 재운다.
#     2. 야채(양파, 고구마, 배추 등)를 준비한다.
#     3. 프라이팬 또는 불판에 기름을 두르고 재운 닭고기와 야채를 함께 볶는다.
#     4. 잘 익으면 참기름을 둘러 기호에 맞게 드신다.
#
# **13:00 - 남이섬 탐방**
# - 남이섬으로 이동 후 자전거 대여, 산책을 하며 섬의 아름다운 자연을 즐깁니다.
#
# **16:00 - 이든밸리 리조트**
# - 이곳에서 짚라인 타기 또는 패러글라이딩 체험 (옵션 선택 가능).
#
# **18:30 - 저녁**
# - **추천 음식:** 송어회
#   - **조리법:**
#     1. 신선한 송어를 잡거나 구매 후, 깨끗하게 손질한다.
#     2. 생선을 얇게 썰어 소금, 간장, 고추가루로 간을 맞춘다.
#     3. 초밥을 곁들여 먹으면 더욱 맛있다.
#
# **20:00 - 숙소 체크인**
# - 가평의 펜션 또는 리조트에 체크인 후 휴식.
#
# ---
#
# #### **2일차: 남양주**
#
# **08:00 - 아침식사**
# - 숙소에서 제공하는 조식 또는 인근 카페에서 간단한 브런치 (예: 토스트와 커피).
#
# **09:30 - 북한강 자전거 도로 탐방**
# - 북한강변의 자전거 도로를 따라 경치를 즐기며 자전거 타기.
#
# **12:00 - 점심**
# - **추천 음식:** 수제버거
#   - **조리법:**
#     1. 소고기 다짐육에 소금, 후추로 간을 맞추고 패티로 만든다.
#     2. 팬에 구워서 바삭한 번에 올린 후, 치즈, 상추, 토마토를 추가한다.
#     3. 케첩과 머스터드로 조리하여 바로 서빙한다.
#
# **14:00 - 남양주 카페 거리 탐방**
# - 유명한 카페 거리에서 커피와 디저트를 즐기며 여유로운 시간 보내기.
#
# **16:00 - 서울로 귀환**
# - 서울로 돌아가는 길에 차에서 자연 경관을 즐깁니다.
#
# ---
#
# 이 일정은 서울 근교의 자연과 문화를 만끽하며, 지역 특색을 살린 음식들을 맛볼 수 있도록 구성되었습니다. 즐거운 여행 되세요!
